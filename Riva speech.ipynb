# %%
# !pip3 install nvidia-riva-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nvidia-riva-client
#   Downloading nvidia_riva_client-2.11.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: setuptools>=65 in /home/carl/.local/lib/python3.8/site-packages (from nvidia-riva-client) (67.8.0)
# Collecting grpcio-tools
#   Downloading grpcio_tools-1.54.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 306.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting grpcio>=1.54.2
#   Downloading grpcio-1.54.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 394.3 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: protobuf<5.0dev,>=4.21.6 in /home/carl/.local/lib/python3.8/site-packages (from grpcio-tools->nvidia-riva-client) (4.23.2)
# Installing collected packages: grpcio, grpcio-tools, nvidia-riva-client
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.51.1
#     Uninstalling grpcio-1.51.1:
#       Successfully uninstalled grpcio-1.51.1
# Successfully installed grpcio-1.54.2 grpcio-tools-1.54.2 nvidia-riva-client-2.11.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.8 -m pip install --upgrade pip

# %%
# !pip3 install --upgrade grpcio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: grpcio in /home/carl/.local/lib/python3.8/site-packages (1.54.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.8 -m pip install --upgrade pip

# %%
import io
import IPython.display as ipd
import grpc

import riva.client

# %%
auth = riva.client.Auth(uri='192.168.16.10:50051')

riva_asr = riva.client.ASRService(auth)

# %%
# This example uses a .wav file with LINEAR_PCM encoding.
# read in an audio file from local disk
path = "download.wav"
with io.open(path, 'rb') as fh:
    content = fh.read()
ipd.Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Set up an offline/batch recognition request
config = riva.client.RecognitionConfig()
#req.config.encoding = ra.AudioEncoding.LINEAR_PCM    # Audio encoding can be detected from wav
#req.config.sample_rate_hertz = 0                     # Sample rate can be detected from wav and resampled if needed
config.language_code = "en-US"                    # Language code of the audio clip
config.max_alternatives = 1                       # How many top-N hypotheses to return
config.enable_automatic_punctuation = True        # Add punctuation when end of VAD detected
config.audio_channel_count = 1                    # Mono channel

# %%
response = riva_asr.offline_recognize(content, config)
asr_best_transcript = response.results[0].alternatives[0].transcript
print("ASR Transcript:", asr_best_transcript)

print("\n\nFull Response Message:")
print(response)
# Out:
# ASR Transcript: Hello World Text to Speech.
#
#
# Full Response Message:
# results {
#   alternatives {
#     transcript: "Hello World Text to Speech. "
#     confidence: -1.40534055
#   }
#   channel_tag: 1
#   audio_processed: 4.8
# }
